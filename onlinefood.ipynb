# %% [markdown]
# <a href="https://colab.research.google.com/github/aamimhd/aamimhd/blob/main/onlinefood.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/onlinefoods.csv')
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate          4.0   12.9766    77.5993    560001
# 1                     Graduate          3.0   12.9770    77.5773    560009
# ...

# %%
df.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   376.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.289894   12.972058   77.600160  560040.113402
# std      2.975593     1.351938    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
df.head(10)
# Out:
#    Age  Gender Marital Status Occupation   Monthly Income  \
# 0   20  Female         Single    Student        No Income
# 1   24  Female         Single    Student   Below Rs.10000
# 2   22    Male         Single    Student   Below Rs.10000
# 3   22  Female         Single    Student        No Income
# 4   22    Male         Single    Student   Below Rs.10000
# 5   27  Female        Married   Employee  More than 50000
# 6   22    Male         Single    Student        No Income
# 7   24  Female         Single    Student        No Income
# 8   23  Female         Single    Student        No Income
# 9   23  Female         Single    Student        No Income
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate          4.0   12.9766    77.5993    560001
# 1                   Graduate          3.0   12.9770    77.5773    560009
# 2              Post Graduate          3.0   12.9551    77.6593    560017
# ...

# %%
df.tail(10)
# Out:
#      Age  Gender Marital Status Occupation   Monthly Income  \
# 378   23  Female         Single   Employee   25001 to 50000
# 379   22    Male         Single    Student   Below Rs.10000
# 380   27  Female        Married   Employee  More than 50000
# 381   22    Male         Single    Student        No Income
# 382   24  Female         Single    Student        No Income
# 383   23  Female         Single    Student        No Income
# 384   23  Female         Single    Student        No Income
# 385   22  Female         Single    Student        No Income
# 386   23    Male         Single    Student   Below Rs.10000
# 387   23    Male         Single    Student        No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 378              Post Graduate          2.0   12.9847    77.5491    560100
# 379              Post Graduate          4.0   12.9850    77.5533    560010
# 380              Post Graduate          2.0   12.9299    77.6848    560103
# ...

# %%
df.shape
# Out:
# (388, 13)

# %%
df.isna().sum()
# Out:
# Age                            0
# Gender                         0
# Marital Status                 5
# Occupation                     7
# Monthly Income                 0
# Educational Qualifications     0
# Family size                   12
# latitude                       0
# longitude                      0
# Pin code                       0
# Output                         0
# Feedback                       3
# Unnamed: 12                    0
# dtype: int64

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Marital Status                 object
# Occupation                     object
# Monthly Income                 object
# Educational Qualifications     object
# Family size                   float64
# latitude                      float64
# longitude                     float64
# Pin code                        int64
# Output                         object
# Feedback                       object
# Unnamed: 12                    object
# dtype: object

# %%
df=df.drop('Unnamed: 12',axis=1)

# %%
df.isna().sum()
# Out:
# Age                            0
# Gender                         0
# Marital Status                 5
# Occupation                     7
# Monthly Income                 0
# Educational Qualifications     0
# Family size                   12
# latitude                       0
# longitude                      0
# Pin code                       0
# Output                         0
# Feedback                       3
# dtype: int64

# %%
df['Marital Status'].fillna(df['Marital Status'].mode()[0],inplace=True)
df['Occupation'].fillna(df['Occupation'].mode()[0],inplace=True)
df['Family size'].fillna(df['Family size'].mode()[0],inplace=True)
df['Feedback'].fillna(df['Feedback'].mode()[0],inplace=True)

df.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# dtype: int64

# %%
f_counts=df['Feedback'].value_counts()
f_counts
# Out:
# Feedback
# Positive     320
# Negative      68
# Name: count, dtype: int64

# %%
f_val=df['Feedback'].unique()
f_val
# Out:
# array(['Positive', 'Negative '], dtype=object)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=f_counts,y=f_val,color='m')
plt.title("FEEDBACK COUNT")
# Out:
# Text(0.5, 1.0, 'FEEDBACK COUNT')

# %%
g_count=df['Gender'].value_counts()
g_count
# Out:
# Gender
# Male      222
# Female    166
# Name: count, dtype: int64

# %%
g_value=df['Gender'].unique()

# %%
plt.pie(g_count,labels=g_value,autopct='%.1f%%',colors=['g','r'])
plt.legend(loc='upper left')
plt.title("Gender distribution")
# Out:
# Text(0.5, 1.0, 'Gender distribution')

# %%
i_count=df['Monthly Income'].value_counts()
i_count
# Out:
# Monthly Income
# No Income          187
# 25001 to 50000      69
# More than 50000     62
# 10001 to 25000      45
# Below Rs.10000      25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(y=df['Monthly Income'],order=i_count.index,color='r')
plt.title("DISTRIBUTION OF MONTHLY INCOME")
plt.xlabel('count')
plt.ylabel('income')
# Out:
# Text(0, 0.5, 'income')

# %%
plt.figure(figsize=(14,8))
sns.countplot(data=df, y='Age', order=df['Age'].value_counts().index[:20],palette='summer')
plt.title('Age')
plt.xlabel('Count')
plt.ylabel('Count')
# Out:
# <ipython-input-306-f5af2b016b68>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='Age', order=df['Age'].value_counts().index[:20],palette='summer')
# Text(0, 0.5, 'Count')

# %%
df['Marital Status'].value_counts()
# Out:
# Marital Status
# Single               273
# Married              103
# Prefer not to say     12
# Name: count, dtype: int64

# %%
a=df['Output'].value_counts()
a1=df['Output'].unique()

# %%
plt.pie(a,labels=a1,autopct='%.1f%%',colors=['pink','b'])
plt.legend(loc='upper left')
plt.title("Output")
# Out:
# Text(0.5, 1.0, 'Output')

# %%
numerical_columns = ['Age', 'Family size', 'latitude', 'longitude', 'Pin code']

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 1, i)
    sns.boxplot(x=df[col],color='red')
    plt.title(f'Box plot of {col}')
    plt.tight_layout()

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Marital Status                 object
# Occupation                     object
# Monthly Income                 object
# Educational Qualifications     object
# Family size                   float64
# latitude                      float64
# longitude                     float64
# Pin code                        int64
# Output                         object
# Feedback                       object
# dtype: object

# %%
df1=pd.get_dummies(df[['Marital Status','Occupation','Monthly Income','Educational Qualifications']],dtype=int,drop_first=True)
df1
# Out:
#      Marital Status_Prefer not to say  Marital Status_Single  \
# 0                                   0                      1
# 1                                   0                      1
# 2                                   0                      1
# 3                                   0                      1
# 4                                   0                      1
# ..                                ...                    ...
# 383                                 0                      1
# 384                                 0                      1
# 385                                 0                      1
# 386                                 0                      1
# 387                                 0                      1
#
#      Occupation_House wife  Occupation_Self Employeed  Occupation_Student  \
# 0                        0                          0                   1
# 1                        0                          0                   1
# ...

# %%
df2=pd.concat([df,df1],axis=1)
df2
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate          4.0   12.9766    77.5993    560001
# 1                     Graduate          3.0   12.9770    77.5773    560009
# ...

# %%
df2.drop(['Marital Status', 'Occupation', 'Monthly Income', 'Educational Qualifications',], axis=1, inplace=True)
df2
# Out:
#      Age  Gender  Family size  latitude  longitude  Pin code Output  \
# 0     20  Female          4.0   12.9766    77.5993    560001    Yes
# 1     24  Female          3.0   12.9770    77.5773    560009    Yes
# 2     22    Male          3.0   12.9551    77.6593    560017    Yes
# 3     22  Female          6.0   12.9473    77.5616    560019    Yes
# 4     22    Male          4.0   12.9850    77.5533    560010    Yes
# ..   ...     ...          ...       ...        ...       ...    ...
# 383   23  Female          2.0   12.9766    77.5993    560001    Yes
# 384   23  Female          4.0   12.9854    77.7081    560048    Yes
# 385   22  Female          5.0   12.9850    77.5533    560010    Yes
# 386   23    Male          2.0   12.9770    77.5773    560009    Yes
# 387   23    Male          5.0   12.8988    77.5764    560078    Yes
#
#       Feedback  Marital Status_Prefer not to say  Marital Status_Single  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
df2["Gender"] = LabelEncoder().fit_transform(df2["Gender"])
df2["Feedback"] = LabelEncoder().fit_transform(df2["Feedback"])
df2
# Out:
#      Age  Gender  Family size  latitude  longitude  Pin code Output  Feedback  \
# 0     20       0          4.0   12.9766    77.5993    560001    Yes         1
# 1     24       0          3.0   12.9770    77.5773    560009    Yes         1
# 2     22       1          3.0   12.9551    77.6593    560017    Yes         0
# 3     22       0          6.0   12.9473    77.5616    560019    Yes         1
# 4     22       1          4.0   12.9850    77.5533    560010    Yes         1
# ..   ...     ...          ...       ...        ...       ...    ...       ...
# 383   23       0          2.0   12.9766    77.5993    560001    Yes         1
# 384   23       0          4.0   12.9854    77.7081    560048    Yes         1
# 385   22       0          5.0   12.9850    77.5533    560010    Yes         1
# 386   23       1          2.0   12.9770    77.5773    560009    Yes         1
# 387   23       1          5.0   12.8988    77.5764    560078    Yes         1
#
# ...

# %%
df2.dtypes
# Out:
# Age                                           int64
# Gender                                        int64
# Family size                                 float64
# latitude                                    float64
# longitude                                   float64
# Pin code                                      int64
# Output                                       object
# Feedback                                      int64
# Marital Status_Prefer not to say              int64
# Marital Status_Single                         int64
# Occupation_House wife                         int64
# Occupation_Self Employeed                     int64
# Occupation_Student                            int64
# Monthly Income_25001 to 50000                 int64
# Monthly Income_Below Rs.10000                 int64
# Monthly Income_More than 50000                int64
# Monthly Income_No Income                      int64
# Educational Qualifications_Ph.D               int64
# ...

# %%
x=df2.drop(['Output'],axis=1).values
x
# Out:
# array([[20.,  0.,  4., ...,  1.,  0.,  0.],
#        [24.,  0.,  3., ...,  0.,  0.,  0.],
#        [22.,  1.,  3., ...,  1.,  0.,  0.],
#        ...,
#        [22.,  0.,  5., ...,  1.,  0.,  0.],
#        [23.,  1.,  2., ...,  1.,  0.,  0.],
#        [23.,  1.,  5., ...,  1.,  0.,  0.]])

# %%
y=df2['Output'].values
y
# Out:
# array(['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No',
#        'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No',
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=32)
x_train
# Out:
# array([[23.,  1.,  5., ...,  1.,  0.,  0.],
#        [31.,  1.,  5., ...,  0.,  0.,  0.],
#        [23.,  0.,  2., ...,  0.,  0.,  0.],
#        ...,
#        [32.,  1.,  5., ...,  0.,  0.,  0.],
#        [22.,  0.,  5., ...,  1.,  0.,  0.],
#        [32.,  1.,  3., ...,  0.,  1.,  0.]])

# %%
y_train
# Out:
# array(['Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes',
#        'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes',
#        'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No',
#        'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
# ...

# %%
x_test
# Out:
# array([[22.,  1.,  2., ...,  0.,  0.,  0.],
#        [25.,  0.,  3., ...,  0.,  0.,  0.],
#        [23.,  0.,  4., ...,  1.,  0.,  0.],
#        ...,
#        [26.,  1.,  3., ...,  1.,  0.,  0.],
#        [23.,  0.,  2., ...,  1.,  0.,  0.],
#        [24.,  0.,  3., ...,  0.,  0.,  0.]])

# %%
y_test
# Out:
# array(['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No',
#        'Yes', 'Yes', 'Yes'], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x_train)
x_train=sc.transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,ConfusionMatrixDisplay

from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(x_train, y_train)


classifier = RandomForestClassifier(n_estimators=200, random_state=1,max_depth=None, min_samples_split=2,min_samples_leaf=2,bootstrap=False)
classifier.fit(X_resampled, y_resampled)


y_pred = classifier.predict(x_test)

labels=['Yes','No']
cmd=ConfusionMatrixDisplay(cm,display_labels=labels)
cmd.plot()

print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)

print(accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.67      0.62      0.64        13
#          Yes       0.92      0.94      0.93        65
#
#     accuracy                           0.88        78
#    macro avg       0.80      0.78      0.79        78
# weighted avg       0.88      0.88      0.88        78
#
# 0.8846153846153846
